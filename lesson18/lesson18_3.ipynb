# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50,5))
scores_pd = pd.DataFrame(scores,columns=['國文', '英文', '數學', '地理', '歷史'],index=range(1,51))
scores_pd.index.name="學號"
scores_pd.columns.name="科目"
scores_pd
# Out:
# 科目  國文   英文   數學   地理  歷史
# 學號
# 1   96   91   68   98  86
# 2   87   73   62   95  79
# 3   63   58   65   99  82
# 4   74   89   61   90  59
# 5   96   55   85   84  82
# 6   95   70   64   55  50
# 7   63   88   94   64  61
# 8   74   79   99   88  62
# 9   64   95   97   76  69
# 10  86   70   52   62  76
# 11  90   68   96   82  64
# 12  59   56   96   62  69
# 13  86   96   53   60  52
# 14  62   51   75   51  69
# 15  70   68   54   50  77
# 16  67   75   90   93  51
# 17  72   67   83   54  92
# 18  63   96   94   51  74
# 19  92   67   87   53  70
# 20  64   95   74   66  53
# 21  75   75   72   60  97
# 22  86   96   57   60  78
# 23  81   84   86  100  63
# 24  78   90   88   97  62
# 25  73   62   73   51  50
# 26  72   64   52   68  80
# 27  97   67   57   57  96
# 28  94   65   84   62  52
# 29  73   78   78   74  99
# 30  57   70   76   52  72
# 31  88   68   51   68  53
# 32  68   59   98   62  63
# 33  82   55   90   79  66
# 34  90   62   71   54  70
# 35  92   93  100   56  65
# 36  75   53   82   87  71
# 37  92   83   92   84  86
# 38  68   92   81   90  52
# 39  78   56   52   92  55
# 40  89   69   51   95  51
# 41  85   66   68   61  73
# 42  67   88   88   51  59
# 43  79   57   63   90  69
# 44  96   51   77   67  81
# 45  83   53   98   50  93
# 46  81   54   82   70  83
# 47  70   66   69   87  52
# 48  63   95   97   92  95
# 49  68  100   62   65  89
# 50  87   89   98   83  97

# %%
def call(s):
    min = s.min()
    max = s.max()
    median = s.median()
    return pd.Series([min, max, median], index=['最低分', '最高分', '中間值'])

scores_pd.apply(call)
# Out:
# 科目     國文     英文     數學     地理    歷史
# 最低分  57.0   51.0   51.0   50.0  50.0
# 最高分  97.0  100.0  100.0  100.0  99.0
# 中間值  78.0   69.5   77.5   67.5  69.5
